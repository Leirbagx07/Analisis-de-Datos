# %% [markdown]
# <a href="https://colab.research.google.com/github/Leirbagx07/Analisis-de-Datos/blob/main/MapaCRPython_(5_puntos_Sedes_UNA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium

# %%
from folium.plugins import minimap

# %%
USA=folium.Map(location=(56.65883, -115.16678))

# %%
USA
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import MiniMap
from branca.element import Figure

popuptext= '<b>Universidad Nacional</b>'

my_map = folium.Map(location=[9.96997699334319, -84.12917454994579], zoom_start=16, tiles='stamenterrain')

#Sede Benjamin Nuñez 9.96997699334319, -84.12917454994579
folium.Marker(location=[9.96997699334319, -84.12917454994579], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[9.96997699334319, -84.12917454994579], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

#Sede Omar Dengo 9.99884245054687, -84.11142924163437
folium.Marker(location=[9.99884245054687, -84.11142924163437], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[9.99884245054687, -84.11142924163437], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

#Sede Interuniversitaria en Alajuela 10.019924033214156, -84.19636014497081
folium.Marker(location=[10.019924033214156, -84.19636014497081], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.019924033214156, -84.19636014497081], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

#Campus en Sarapiqui 10.319308351063054, -83.92192095476894
folium.Marker(location=[10.319308351063054, -83.92192095476894], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.319308351063054, -83.92192095476894], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

#Campus Coto 8.573514234643122, -82.87180160265058
folium.Marker(location=[8.573514234643122, -82.87180160265058], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[8.573514234643122, -82.87180160265058], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

#Campus Perez Zeledon 9.381233709637922, -83.69189314166006
folium.Marker(location=[9.381233709637922, -83.69189314166006], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[9.381233709637922, -83.69189314166006], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

#Campus Liberia 10.617587905589108, -85.45137535862361
folium.Marker(location=[10.617587905589108, -85.45137535862361], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.617587905589108, -85.45137535862361], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

#Campus Nicoya 10.61818924151975, -85.45072115034067
folium.Marker(location=[10.61818924151975, -85.45072115034067], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.61818924151975, -85.45072115034067], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltip="Benjamin Nuñez").add_to(my_map)

minimap= MiniMap(tile_layer='stamenterrain', position='bottomright')
my_map.add_child(minimap)

my_map.save('C:mapa.html')
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
